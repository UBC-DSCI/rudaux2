# %%
import requests
import os
import urllib.parse
import posixpath
import pandas as pd
import paramiko
from traitlets.config import Config
from traitlets.config.application import Application

# %%
# All the settings for the assignment (will become script arguments)
assignment = 'worksheet_01'
due_day = 'sat' # should be sat or wed
grader = 'timberst' # should be graders cwl

# %%
# make course an object
class course():
    
    def __init__(self, canvasHostName, courseID):
        self.canvasHostName = canvasHostName
        self.courseID = courseID
        print('Create class with Canvas host name:{0} and course ID: {1})'.
              format(self.canvasHostName, self.courseID))
        
    def get_student_ids(self):
        '''Read Canvas authentication token from an environment variable, takes a
        Canvas host name (includes https://) and the Canvas course id and returns
        a list of the student id's of all students currently enrolled in the course.
    
        Example:
        course.get_student_ids()'''
        #canvas_token = rudaux2_config.CANVAS_TOKEN
        canvas_token = os.environ["CANVAS_TOKEN"]
        url_path = posixpath.join("api", "v1", "courses", self.courseID, "enrollments")
        api_url = urllib.parse.urljoin(self.canvasHostName, url_path)
        resp = requests.get(
              url = api_url,
              headers = {
                "Authorization": f"Bearer {canvas_token}",
                "Accept": "application/json+canvas-string-ids"
              },
              json={
                "enrollment_type": ["student"],
                "per_page": "500"
              },
            )
        students = resp.json()
        student_id = []
        for student in students:
            student_id.append(student['user_id'])
        return student_id
    
    
    def get_student_info(self):
        '''Read Canvas authentication token from an environment variable, takes a
        Canvas host name (includes https://) and the Canvas course id and returns
        a list of the student id's, given and surnames of all students currently 
        enrolled in the course.
    
        Example:
        course.get_student_info()'''
        canvas_token = os.environ["CANVAS_TOKEN"]
        url_path = posixpath.join("api", "v1", "courses", self.courseID, "enrollments")
        api_url = urllib.parse.urljoin(self.canvasHostName, url_path)
        resp = requests.get(
              url = api_url,
              headers = {
                "Authorization": f"Bearer {canvas_token}",
                "Accept": "application/json+canvas-string-ids"
              },
              json={
                "enrollment_type": ["student"],
                "per_page": "500"
              },
            )
        students = resp.json()
        return students
    
    def get_assignments(self):
        '''Read Canvas authentication token from an environment variable, takes a
        Canvas host name (includes https://) and the Canvas course id and returns
        a Pandas data frame with all existing assignments and their attributes/data

        Example:
        course.get_assignments()'''
        #canvas_token = rudaux2_config.CANVAS_TOKEN
        canvas_token = os.environ["CANVAS_TOKEN"]
        url_path = posixpath.join("api", "v1", "courses", self.courseID, "assignments")
        api_url = urllib.parse.urljoin(self.canvasHostName, url_path)
        resp = requests.get(
          url=api_url,
          headers={
            "Authorization": f"Bearer {canvas_token}",
            "Accept": "application/json+canvas-string-ids"
          },
          json={
            "per_page": "2000"
          },
        )
        assignments = resp.json()
        assign_data = pd.DataFrame.from_dict(assignments)
        return assign_data
    
    def get_assignment_due_date(self, assignment):
        '''Takes the name of a Canvas assignment and returns the due date.
        
        Example:
        course.get_assignment_due_date('worksheet_01')'''
        assignments = self.get_assignments()
        assignment = assignments[['name', 'due_at']].query('name == @assignment')
        due_date = assignment['due_at'].to_numpy()[0]
        due_date = due_date.replace("T", "-")
        due_date = due_date.replace(":", "-")
        return due_date[:16]

# %%
# All the settings for the course - so go in a config file
dsci100_canvasHostName = "https://canvas.ubc.ca"
dsci100_courseID = "40616"
course_storage_path = '/tank/home/dsci100'
stu_repo_name = 'dsci-100'
ins_repo_name = 'dsci-100-instructor'
assignment_release_path = 'materials'
snapshot_prefix = 'zfs-auto-snap_'
snapshot_delay = '10'

# %%
dsci100 = course(dsci100_canvasHostName, dsci100_courseID) # get these values 
students = dsci100.get_student_info()
# Out:
# Create class with Canvas host name:https://canvas.ubc.ca and course ID: 40616)

# %%
students
# Out:
# [{'id': '1682992',
#   'user_id': '313452',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-21T00:35:19Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T01:30:58Z',
#   'last_attended_at': None,
#   'total_activity_time': 1331,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/313452',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '33687591',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/313452',
#   'user': {'id': '313452',
#    'name': 'Jerome Ah Ching',
#    'created_at': '2018-12-15T01:00:48-08:00',
#    'sortable_name': 'Ah Ching, Jerome',
#    'short_name': 'Jerome Ah Ching',
#    'sis_user_id': '33687591',
#    'integration_id': 'XDJW7ALTN601'}},
#  {'id': '1511863',
#   'user_id': '22653',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-12T00:32:40Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-10T16:14:18Z',
#   'last_attended_at': None,
#   'total_activity_time': 2312,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/22653',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '14890164',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/22653',
#   'user': {'id': '22653',
#    'name': 'Zaha Al-hmoud',
#    'created_at': '2017-08-25T01:14:09-07:00',
#    'sortable_name': 'Al-hmoud, Zaha',
#    'short_name': 'Zaha Al-hmoud',
#    'sis_user_id': '14890164',
#    'integration_id': 'JPH4GT08MB05'}},
#  {'id': '2208067',
#   'user_id': '353207',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-09-06T21:09:45Z',
#   'updated_at': '2019-09-06T21:09:45Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T01:28:00Z',
#   'last_attended_at': None,
#   'total_activity_time': 4071,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/353207',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '11797586',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/353207',
#   'user': {'id': '353207',
#    'name': 'Frederick Althaus',
#    'created_at': '2019-02-16T01:02:19-08:00',
#    'sortable_name': 'Althaus, Frederick',
#    'short_name': 'Frederick Althaus',
#    'sis_user_id': '11797586',
#    'integration_id': 'HDA2MSY9Z600'}},
#  {'id': '1604293',
#   'user_id': '245299',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-18T16:32:23Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T05:43:50Z',
#   'last_attended_at': None,
#   'total_activity_time': 3818,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/245299',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '25056623',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/245299',
#   'user': {'id': '245299',
#    'name': 'Mert Barutcuoglu',
#    'created_at': '2018-09-25T01:09:28-07:00',
#    'sortable_name': 'Barutcuoglu, Mert',
#    'short_name': 'Mert Barutcuoglu',
#    'sis_user_id': '25056623',
#    'integration_id': 'XLWMKPN21E09'}},
#  {'id': '2208083',
#   'user_id': '38443',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-09-06T21:11:00Z',
#   'updated_at': '2019-09-06T21:11:00Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T05:34:49Z',
#   'last_attended_at': None,
#   'total_activity_time': 2464,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/38443',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '42620161',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/38443',
#   'user': {'id': '38443',
#    'name': 'Kajal Bhagat',
#    'created_at': '2017-09-02T23:15:18-07:00',
#    'sortable_name': 'Bhagat, Kajal',
#    'short_name': 'Kajal Bhagat',
#    'sis_user_id': '42620161',
#    'integration_id': 'GLYZM9QFD503'}},
#  {'id': '1707833',
#   'user_id': '236528',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-21T11:27:03Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T01:03:08Z',
#   'last_attended_at': None,
#   'total_activity_time': 3323,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/236528',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '35333582',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/236528',
#   'user': {'id': '236528',
#    'name': 'Maryam Bhalloo',
#    'created_at': '2018-09-14T01:08:43-07:00',
#    'sortable_name': 'Bhalloo, Maryam',
#    'short_name': 'Maryam Bhalloo',
#    'sis_user_id': '35333582',
#    'integration_id': 'S4NA1TI3QY06'}},
#  {'id': '2095474',
#   'user_id': '52211',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-08-14T21:31:22Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T02:12:03Z',
#   'last_attended_at': None,
#   'total_activity_time': 3513,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/52211',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '39210653',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/52211',
#   'user': {'id': '52211',
#    'name': 'Achinth Bharadwaj',
#    'created_at': '2017-09-13T11:36:08-07:00',
#    'sortable_name': 'Bharadwaj, Achinth',
#    'short_name': 'Achinth Bharadwaj',
#    'sis_user_id': '39210653',
#    'integration_id': 'B0HAKQROI407'}},
#  {'id': '1759638',
#   'user_id': '243174',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-25T15:56:59Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T03:36:40Z',
#   'last_attended_at': None,
#   'total_activity_time': 7031,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/243174',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '19136043',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/243174',
#   'user': {'id': '243174',
#    'name': 'Emma Boggan',
#    'created_at': '2018-09-22T01:01:11-07:00',
#    'sortable_name': 'Boggan, Emma',
#    'short_name': 'Emma Boggan',
#    'sis_user_id': '19136043',
#    'integration_id': 'U45JKWYT2606'}},
#  {'id': '1588972',
#   'user_id': '355215',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-14T17:19:01Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T02:53:57Z',
#   'last_attended_at': None,
#   'total_activity_time': 1967,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/355215',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '61286878',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/355215',
#   'user': {'id': '355215',
#    'name': 'Adam Chew',
#    'created_at': '2019-02-26T01:01:02-08:00',
#    'sortable_name': 'Chew, Adam',
#    'short_name': 'Adam Chew',
#    'sis_user_id': '61286878',
#    'integration_id': '6YLZX734EC06'}},
#  {'id': '2095411',
#   'user_id': '72598',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-08-14T21:13:33Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T01:07:18Z',
#   'last_attended_at': None,
#   'total_activity_time': 3783,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/72598',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '30736920',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/72598',
#   'user': {'id': '72598',
#    'name': 'Samantha Chiang',
#    'created_at': '2017-10-02T12:08:01-07:00',
#    'sortable_name': 'Chiang, Samantha',
#    'short_name': 'Samantha Chiang',
#    'sis_user_id': '30736920',
#    'integration_id': 'EFKGPXA0O104'}},
#  {'id': '2141483',
#   'user_id': '53263',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-08-28T22:12:56Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T03:58:35Z',
#   'last_attended_at': None,
#   'total_activity_time': 13259,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/53263',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '44277408',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/53263',
#   'user': {'id': '53263',
#    'name': 'Allan Cho',
#    'created_at': '2017-09-13T11:43:23-07:00',
#    'sortable_name': 'Cho, Allan',
#    'short_name': 'Allan Cho',
#    'sis_user_id': '44277408',
#    'integration_id': 'W06C9JDYI502'}},
#  {'id': '1590671',
#   'user_id': '367639',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-14T18:51:43Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T02:51:58Z',
#   'last_attended_at': None,
#   'total_activity_time': 1909,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/367639',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '39406343',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/367639',
#   'user': {'id': '367639',
#    'name': 'Hui Shun Chua',
#    'created_at': '2019-04-28T01:00:49-07:00',
#    'sortable_name': 'Chua, Hui Shun',
#    'short_name': 'Hui Shun Chua',
#    'sis_user_id': '39406343',
#    'integration_id': '4CFKTAUNYX09'}},
#  {'id': '1763399',
#   'user_id': '50502',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-25T17:22:35Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-10T21:28:28Z',
#   'last_attended_at': None,
#   'total_activity_time': 4053,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/50502',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '28401313',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/50502',
#   'user': {'id': '50502',
#    'name': 'David Ewert',
#    'created_at': '2017-09-13T11:23:38-07:00',
#    'sortable_name': 'Ewert, David',
#    'short_name': 'David Ewert',
#    'sis_user_id': '28401313',
#    'integration_id': 'SC4T9U8OKZ06'}},
#  {'id': '1699680',
#   'user_id': '347589',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-21T07:59:14Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T05:00:37Z',
#   'last_attended_at': None,
#   'total_activity_time': 4927,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/347589',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '47911821',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/347589',
#   'user': {'id': '347589',
#    'name': 'Thomas Alexander Frost',
#    'created_at': '2019-01-26T01:02:28-08:00',
#    'sortable_name': 'Frost, Thomas Alexander',
#    'short_name': 'Thomas Alexander Frost',
#    'sis_user_id': '47911821',
#    'integration_id': 'G9T034KLHU08'}},
#  {'id': '2066387',
#   'user_id': '21117',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-07-31T22:58:07Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T18:39:38Z',
#   'last_attended_at': None,
#   'total_activity_time': 3365,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/21117',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '27972892',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/21117',
#   'user': {'id': '21117',
#    'name': 'Kaycee Galenzoski',
#    'created_at': '2017-08-25T00:23:55-07:00',
#    'sortable_name': 'Galenzoski, Kaycee',
#    'short_name': 'Kaycee Galenzoski',
#    'sis_user_id': '27972892',
#    'integration_id': '6OT2VCQZ1B02'}},
#  {'id': '1595574',
#   'user_id': '10946',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-17T06:15:10Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-10T20:16:57Z',
#   'last_attended_at': None,
#   'total_activity_time': 2635,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/10946',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '47584164',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/10946',
#   'user': {'id': '10946',
#    'name': 'RACHEL GAO',
#    'created_at': '2017-08-24T12:49:49-07:00',
#    'sortable_name': 'GAO, RACHEL',
#    'short_name': 'RACHEL GAO',
#    'sis_user_id': '47584164',
#    'integration_id': 'MXUI380RSO04'}},
#  {'id': '1743728',
#   'user_id': '276319',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-22T04:11:21Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T00:31:53Z',
#   'last_attended_at': None,
#   'total_activity_time': 1858,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/276319',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '90695412',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/276319',
#   'user': {'id': '276319',
#    'name': 'Ashish Gnawali',
#    'created_at': '2018-11-04T01:09:38-08:00',
#    'sortable_name': 'Gnawali, Ashish',
#    'short_name': 'Ashish Gnawali',
#    'sis_user_id': '90695412',
#    'integration_id': 'YZCSXJGHNB00'}},
#  {'id': '1589506',
#   'user_id': '365927',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-14T17:46:29Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T03:49:12Z',
#   'last_attended_at': None,
#   'total_activity_time': 4292,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/365927',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '14125496',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/365927',
#   'user': {'id': '365927',
#    'name': 'Guilherme Gomes Luz',
#    'created_at': '2019-04-18T01:02:21-07:00',
#    'sortable_name': 'Gomes Luz, Guilherme',
#    'short_name': 'Guilherme Gomes Luz',
#    'sis_user_id': '14125496',
#    'integration_id': 'LVITGO9D7406'}},
#  {'id': '1641191',
#   'user_id': '265258',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-19T23:42:04Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T00:03:16Z',
#   'last_attended_at': None,
#   'total_activity_time': 2208,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/265258',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '33464504',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/265258',
#   'user': {'id': '265258',
#    'name': 'Lukas Guderjahn',
#    'created_at': '2018-10-22T01:05:07-07:00',
#    'sortable_name': 'Guderjahn, Lukas',
#    'short_name': 'Lukas Guderjahn',
#    'sis_user_id': '33464504',
#    'integration_id': 'PLCRNZSKU902'}},
#  {'id': '2232832',
#   'user_id': '14051',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-09-11T15:22:06Z',
#   'updated_at': '2019-09-11T15:22:06Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T22:00:38Z',
#   'last_attended_at': None,
#   'total_activity_time': 133,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/14051',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '23418015',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/14051',
#   'user': {'id': '14051',
#    'name': 'Yining Guo',
#    'created_at': '2017-08-24T14:42:38-07:00',
#    'sortable_name': 'Guo, Yining',
#    'short_name': 'Yining Guo',
#    'sis_user_id': '23418015',
#    'integration_id': '2UPGLZ9AYQ06'}},
#  {'id': '1590691',
#   'user_id': '362409',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-14T18:52:46Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T18:06:56Z',
#   'last_attended_at': None,
#   'total_activity_time': 4412,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/362409',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '93227601',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/362409',
#   'user': {'id': '362409',
#    'name': 'Sara Haghani',
#    'created_at': '2019-03-31T01:01:39-07:00',
#    'sortable_name': 'Haghani, Sara',
#    'short_name': 'Sara Haghani',
#    'sis_user_id': '93227601',
#    'integration_id': 'ZHCQMOI63007'}},
#  {'id': '2207662',
#   'user_id': '215514',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-09-06T20:28:14Z',
#   'updated_at': '2019-09-06T20:28:14Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T21:43:08Z',
#   'last_attended_at': None,
#   'total_activity_time': 3300,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/215514',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '46068136',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/215514',
#   'user': {'id': '215514',
#    'name': 'Katie Hong',
#    'created_at': '2018-07-05T23:23:32-07:00',
#    'sortable_name': 'Hong, Katie',
#    'short_name': 'Katie Hong',
#    'sis_user_id': '46068136',
#    'integration_id': 'XB2G76IA5100'}},
#  {'id': '1684480',
#   'user_id': '253244',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-21T01:14:18Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T00:35:10Z',
#   'last_attended_at': None,
#   'total_activity_time': 2607,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/253244',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '78305794',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/253244',
#   'user': {'id': '253244',
#    'name': 'Jasper Huang',
#    'created_at': '2018-10-06T01:02:15-07:00',
#    'sortable_name': 'Huang, Jasper',
#    'short_name': 'Jasper Huang',
#    'sis_user_id': '78305794',
#    'integration_id': '1OICXDM8KN02'}},
#  {'id': '2178325',
#   'user_id': '33863',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-09-04T17:41:32Z',
#   'updated_at': '2019-09-04T17:41:32Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T01:15:53Z',
#   'last_attended_at': None,
#   'total_activity_time': 2101,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/33863',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '57641169',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/33863',
#   'user': {'id': '33863',
#    'name': 'Egemen Inal',
#    'created_at': '2017-08-31T18:04:02-07:00',
#    'sortable_name': 'Inal, Egemen',
#    'short_name': 'Egemen Inal',
#    'sis_user_id': '57641169',
#    'integration_id': 'BIG8YXF47500'}},
#  {'id': '2208106',
#   'user_id': '18114',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-09-06T21:13:21Z',
#   'updated_at': '2019-09-06T21:13:21Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T18:07:24Z',
#   'last_attended_at': None,
#   'total_activity_time': 30485,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/18114',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '19923151',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/18114',
#   'user': {'id': '18114',
#    'name': 'Justin Jao',
#    'created_at': '2017-08-24T22:55:33-07:00',
#    'sortable_name': 'Jao, Justin',
#    'short_name': 'Justin Jao',
#    'sis_user_id': '19923151',
#    'integration_id': '613CDTOA4Z05'}},
#  {'id': '1744123',
#   'user_id': '293014',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-22T04:23:54Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T03:11:19Z',
#   'last_attended_at': None,
#   'total_activity_time': 5203,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/293014',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '17166653',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/293014',
#   'user': {'id': '293014',
#    'name': 'Sina Khademolhosseini',
#    'created_at': '2018-11-23T01:09:51-08:00',
#    'sortable_name': 'Khademolhosseini, Sina',
#    'short_name': 'Sina Khademolhosseini',
#    'sis_user_id': '17166653',
#    'integration_id': 'ED7UNL0AYG08'}},
#  {'id': '1513715',
#   'user_id': '18506',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-12T01:25:42Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T04:54:15Z',
#   'last_attended_at': None,
#   'total_activity_time': 1713,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/18506',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '11471159',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/18506',
#   'user': {'id': '18506',
#    'name': 'Alex Lau',
#    'created_at': '2017-08-24T23:08:03-07:00',
#    'sortable_name': 'Lau, Alex',
#    'short_name': 'Alex Lau',
#    'sis_user_id': '11471159',
#    'integration_id': '6UJYWFKPA006'}},
#  {'id': '2066372',
#   'user_id': '72633',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-07-31T22:51:22Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T01:28:00Z',
#   'last_attended_at': None,
#   'total_activity_time': 25249,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/72633',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '83231506',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/72633',
#   'user': {'id': '72633',
#    'name': 'Kevin Le',
#    'created_at': '2017-10-02T12:08:19-07:00',
#    'sortable_name': 'Le, Kevin',
#    'short_name': 'Kevin Le',
#    'sis_user_id': '83231506',
#    'integration_id': '16BX8GDNV400'}},
#  {'id': '1595703',
#   'user_id': '16635',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-17T09:52:42Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T05:11:18Z',
#   'last_attended_at': None,
#   'total_activity_time': 8483,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/16635',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '84326776',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/16635',
#   'user': {'id': '16635',
#    'name': 'Daniel Lee',
#    'created_at': '2017-08-24T22:13:23-07:00',
#    'sortable_name': 'Lee, Daniel',
#    'short_name': 'Daniel Lee',
#    'sis_user_id': '84326776',
#    'integration_id': '9AUBVT4F3603'}},
#  {'id': '1717148',
#   'user_id': '137318',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-21T17:03:25Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T22:02:01Z',
#   'last_attended_at': None,
#   'total_activity_time': 1256,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/137318',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '81741001',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/137318',
#   'user': {'id': '137318',
#    'name': 'Michelle Lee',
#    'created_at': '2017-12-04T01:00:20-08:00',
#    'sortable_name': 'Lee, Michelle',
#    'short_name': 'Michelle Lee',
#    'sis_user_id': '81741001',
#    'integration_id': 'J0XA49HWPY03'}},
#  {'id': '1688681',
#   'user_id': '291347',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-21T03:15:38Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-11T20:29:43Z',
#   'last_attended_at': None,
#   'total_activity_time': 5499,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/291347',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '68834183',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/291347',
#   'user': {'id': '291347',
#    'name': 'Tianne Lee',
#    'created_at': '2018-11-21T01:18:53-08:00',
#    'sortable_name': 'Lee, Tianne',
#    'short_name': 'Tianne Lee',
#    'sis_user_id': '68834183',
#    'integration_id': 'A8OXJNYDCT02'}},
#  {'id': '1478542',
#   'user_id': '79214',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-06T08:56:55Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': None,
#   'last_attended_at': None,
#   'total_activity_time': 0,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/79214',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '69613578',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/79214',
#   'user': {'id': '79214',
#    'name': 'GEENA LITTEL',
#    'created_at': '2017-10-09T01:00:56-07:00',
#    'sortable_name': 'LITTEL, GEENA',
#    'short_name': 'GEENA LITTEL',
#    'sis_user_id': '69613578',
#    'integration_id': 'CIKRAJO32S05'}},
#  {'id': '1585153',
#   'user_id': '15374',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-14T05:51:07Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
# ...
#   'sis_user_id': '51562156',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/20861',
#   'user': {'id': '20861',
#    'name': 'Cynthia Wu',
#    'created_at': '2017-08-25T00:16:43-07:00',
#    'sortable_name': 'Wu, Cynthia',
#    'short_name': 'Cynthia Wu',
#    'sis_user_id': '51562156',
#    'integration_id': 'PENU35IAS206'}},
#  {'id': '1622210',
#   'user_id': '305985',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-19T05:02:49Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-10T20:18:50Z',
#   'last_attended_at': None,
#   'total_activity_time': 7207,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/305985',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '29966892',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/305985',
#   'user': {'id': '305985',
#    'name': 'Tommy Xu',
#    'created_at': '2018-12-06T01:08:39-08:00',
#    'sortable_name': 'Xu, Tommy',
#    'short_name': 'Tommy Xu',
#    'sis_user_id': '29966892',
#    'integration_id': '7YLN0AIEOW05'}},
#  {'id': '2229279',
#   'user_id': '359449',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-09-10T21:12:23Z',
#   'updated_at': '2019-09-10T21:12:23Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': None,
#   'last_attended_at': None,
#   'total_activity_time': 0,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/359449',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '52134665',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/359449',
#   'user': {'id': '359449',
#    'name': 'Cheng Hui YAO',
#    'created_at': '2019-03-17T01:00:12-07:00',
#    'sortable_name': 'YAO, Cheng Hui',
#    'short_name': 'Cheng Hui YAO',
#    'sis_user_id': '52134665',
#    'integration_id': 'QI1KX3TGH202'}},
#  {'id': '1768799',
#   'user_id': '61373',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-06-25T19:36:43Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T01:36:04Z',
#   'last_attended_at': None,
#   'total_activity_time': 10734,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/61373',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '89906366',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/61373',
#   'user': {'id': '61373',
#    'name': 'Danyang Yin',
#    'created_at': '2017-09-18T12:34:46-07:00',
#    'sortable_name': 'Yin, Danyang',
#    'short_name': 'Danyang Yin',
#    'sis_user_id': '89906366',
#    'integration_id': 'T6QK7LEPO009'}},
#  {'id': '2166552',
#   'user_id': '113345',
#   'course_id': '40616',
#   'type': 'StudentEnrollment',
#   'created_at': '2019-09-03T17:33:17Z',
#   'updated_at': '2019-09-03T17:33:17Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-12T04:25:03Z',
#   'last_attended_at': None,
#   'total_activity_time': 2599,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/113345',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '16219784',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/113345',
#   'user': {'id': '113345',
#    'name': 'Kassandra Zhou',
#    'created_at': '2017-11-11T01:00:56-08:00',
#    'sortable_name': 'Zhou, Kassandra',
#    'short_name': 'Kassandra Zhou',
#    'sis_user_id': '16219784',
#    'integration_id': 'GXST3HR2ZC09'}},
#  {'id': '2079970',
#   'user_id': '397133',
#   'course_id': '40616',
#   'type': 'StudentViewEnrollment',
#   'created_at': '2019-08-07T20:18:30Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'StudentEnrollment',
#   'role_id': '3',
#   'last_activity_at': '2019-09-10T18:38:58Z',
#   'last_attended_at': None,
#   'total_activity_time': 1216,
#   'grades': {'html_url': 'https://canvas.ubc.ca/courses/40616/grades/397133',
#    'current_grade': None,
#    'current_score': None,
#    'final_grade': None,
#    'final_score': 0.0,
#    'unposted_current_score': None,
#    'unposted_current_grade': None,
#    'unposted_final_score': 0.0,
#    'unposted_final_grade': None},
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': None,
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/397133',
#   'user': {'id': '397133',
#    'name': 'Test Student',
#    'created_at': '2019-08-07T13:18:30-07:00',
#    'sortable_name': 'Student, Test',
#    'short_name': 'Test Student',
#    'sis_user_id': None,
#    'integration_id': None}},
#  {'id': '2188320',
#   'user_id': '73290',
#   'course_id': '40616',
#   'type': 'TaEnrollment',
#   'created_at': '2019-09-05T05:02:01Z',
#   'updated_at': '2019-09-05T05:02:01Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'TaEnrollment',
#   'role_id': '5',
#   'last_activity_at': '2019-09-12T01:22:27Z',
#   'last_attended_at': None,
#   'total_activity_time': 6263,
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '41046996',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/73290',
#   'user': {'id': '73290',
#    'name': 'Daniel Alimohd',
#    'created_at': '2017-10-02T12:20:02-07:00',
#    'sortable_name': 'Alimohd, Daniel',
#    'short_name': 'Daniel Alimohd',
#    'sis_user_id': '41046996',
#    'integration_id': '1MVIB3QF5708'}},
#  {'id': '2188321',
#   'user_id': '90233',
#   'course_id': '40616',
#   'type': 'TaEnrollment',
#   'created_at': '2019-09-05T05:02:03Z',
#   'updated_at': '2019-09-05T05:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'TaEnrollment',
#   'role_id': '5',
#   'last_activity_at': '2019-09-08T00:13:38Z',
#   'last_attended_at': None,
#   'total_activity_time': 0,
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '48510689',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/90233',
#   'user': {'id': '90233',
#    'name': 'Jordan Bourak',
#    'created_at': '2017-10-19T01:02:44-07:00',
#    'sortable_name': 'Bourak, Jordan',
#    'short_name': 'Jordan Bourak',
#    'sis_user_id': '48510689',
#    'integration_id': '4JHBWTN3YE05'}},
#  {'id': '2156875',
#   'user_id': '26115',
#   'course_id': '40616',
#   'type': 'TaEnrollment',
#   'created_at': '2019-08-30T23:41:15Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'TaEnrollment',
#   'role_id': '5',
#   'last_activity_at': '2019-09-11T23:00:17Z',
#   'last_attended_at': None,
#   'total_activity_time': 2989,
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '63372163',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/26115',
#   'user': {'id': '26115',
#    'name': 'Alex Chow',
#    'created_at': '2017-08-25T03:23:38-07:00',
#    'sortable_name': 'Chow, Alex',
#    'short_name': 'Alex Chow',
#    'sis_user_id': '63372163',
#    'integration_id': 'XG1F7MLT8H04'}},
#  {'id': '2174531',
#   'user_id': '50482',
#   'course_id': '40616',
#   'type': 'TaEnrollment',
#   'created_at': '2019-09-04T04:01:12Z',
#   'updated_at': '2019-09-04T04:01:12Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'TaEnrollment',
#   'role_id': '5',
#   'last_activity_at': '2019-09-11T16:20:50Z',
#   'last_attended_at': None,
#   'total_activity_time': 4277,
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '65956328',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/50482',
#   'user': {'id': '50482',
#    'name': 'Grandon Seto',
#    'created_at': '2017-09-13T11:23:27-07:00',
#    'sortable_name': 'Seto, Grandon',
#    'short_name': 'Grandon Seto',
#    'sis_user_id': '65956328',
#    'integration_id': '7MN14SRXUB09'}},
#  {'id': '2174530',
#   'user_id': '60469',
#   'course_id': '40616',
#   'type': 'TaEnrollment',
#   'created_at': '2019-09-04T04:01:11Z',
#   'updated_at': '2019-09-04T04:01:11Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'TaEnrollment',
#   'role_id': '5',
#   'last_activity_at': '2019-09-11T22:45:18Z',
#   'last_attended_at': None,
#   'total_activity_time': 379,
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': '59808642',
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/60469',
#   'user': {'id': '60469',
#    'name': 'Petal Vitis',
#    'created_at': '2017-09-17T09:09:44-07:00',
#    'sortable_name': 'Vitis, Petal',
#    'short_name': 'Petal Vitis',
#    'sis_user_id': '59808642',
#    'integration_id': 'DWVMQCBF3207'}},
#  {'id': '1478545',
#   'user_id': '216528',
#   'course_id': '40616',
#   'type': 'TeacherEnrollment',
#   'created_at': '2019-06-06T08:56:56Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'TeacherEnrollment',
#   'role_id': '4',
#   'last_activity_at': '2019-09-11T06:48:20Z',
#   'last_attended_at': None,
#   'total_activity_time': 38311,
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': None,
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/216528',
#   'user': {'id': '216528',
#    'name': 'Trevor Campbell',
#    'created_at': '2018-07-07T01:09:42-07:00',
#    'sortable_name': 'Campbell, Trevor',
#    'short_name': 'Trevor Campbell',
#    'sis_user_id': None,
#    'integration_id': '3QY0KNS6C200'}},
#  {'id': '1478543',
#   'user_id': '176480',
#   'course_id': '40616',
#   'type': 'TeacherEnrollment',
#   'created_at': '2019-06-06T08:56:56Z',
#   'updated_at': '2019-09-03T06:02:03Z',
#   'associated_user_id': None,
#   'start_at': None,
#   'end_at': None,
#   'course_section_id': '44261',
#   'root_account_id': '1',
#   'limit_privileges_to_course_section': False,
#   'enrollment_state': 'active',
#   'role': 'TeacherEnrollment',
#   'role_id': '4',
#   'last_activity_at': '2019-09-12T05:36:05Z',
#   'last_attended_at': None,
#   'total_activity_time': 24668,
#   'sis_account_id': 'SIS.UBC.DSCI',
#   'sis_course_id': 'cbbee518-6eb4-4387-b35f-d06ea8362a26',
#   'course_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_section_id': None,
#   'section_integration_id': 'ID:ctprod01.lms.it.ubc.ca-37392-1555510350708-1253829:1:648:1:1',
#   'sis_user_id': None,
#   'html_url': 'https://canvas.ubc.ca/courses/40616/users/176480',
#   'user': {'id': '176480',
#    'name': 'Tiffany Timbers',
#    'created_at': '2018-01-15T15:51:58-08:00',
#    'sortable_name': 'Timbers, Tiffany',
#    'short_name': 'Tiffany Timbers',
#    'sis_user_id': None,
#    'integration_id': '7WUEFKNYJ302'}}]

# %%
# Code to run
dsci100 = course(canvasHostName, courseID) # get these values 
students = dsci100.get_student_ids()
due_date = dsci100.get_assignment_due_date(assignment)[:13]

# Create copy from and to paths
copy_from_path = os.path.join('.zfs', 'snapshot', snapshot_prefix + due_day + '-' + due_date + snapshot_delay)
copy_to_path = os.path.join(course_storage_path, grader, ins_repo_name, 'submitted')

# %%
ssh = paramiko.SSHClient() 
ssh.load_host_keys(os.path.expanduser(os.path.join("~", ".ssh", "known_hosts")))
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh.connect("hub-prod-dsci.stat.ubc.ca", username="stty2u")
sftp = ssh.open_sftp()

# %%
#student_path_remote = os.path.join(course_storage_path, str(students[0]))

# %%
#assignment_path = os.path.join(student_path_remote, copy_from_path, stu_repo_name, assignment_release_path, assignment, assignment + '.ipynb')

# %%
#student_path_local = os.path.join(copy_to_path, str(students[0]))

# %%
#submission_path = os.path.join(student_path_local, assignment, assignment + '.ipynb')

# %%
#if not os.path.exists(student_path_local):
#    os.mkdir(student_path_local)
#    os.mkdir(os.path.join(student_path_local, assignment))  
#else:   
#    if not os.path.exists(os.path.join(student_path_local, assignment)):
#        os.mkdir(os.path.join(student_path_local, assignment))

# %%
#sftp.get(remotepath=assignment_path, localpath=submission_path)

# %%
# looping over student id
for student in students:
    student_path_remote = os.path.join(course_storage_path, str(student))
    assignment_path = os.path.join(student_path_remote, copy_from_path, stu_repo_name, assignment_release_path, assignment, assignment + '.ipynb')
    student_path_local = os.path.join(copy_to_path, str(student))
    submission_path = os.path.join(student_path_local, assignment, assignment + '.ipynb')
    
    if not os.path.exists(student_path_local):
        os.mkdir(student_path_local)
        os.mkdir(os.path.join(student_path_local, assignment))  
    else:   
        if not os.path.exists(os.path.join(student_path_local, assignment)):
            os.mkdir(os.path.join(student_path_local, assignment))
    try:
        sftp.get(remotepath=assignment_path, localpath=submission_path)
    except:
      pass

# %%
sftp.close()
ssh.close()
